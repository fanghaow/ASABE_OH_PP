# %%
import numpy as np
from math import *
import cv2
import time
import os,sys
import matplotlib.pyplot as plt

# %%
path = 'randomimg/'
img = cv2.imread(path + str(10000+8) + '.jpg',1)
plt.imshow(img)
